# %% [markdown]
# # Introduction
#
# Lorem Ipsum...
#
# In this example we will be computing the *radial distribution function* TODO add link to documentation...when that documentation is online...get that added to the website!
#
# To calculate the radial distribution function TODO (add in math to actual section?), we will need to follow the following workflow:
#
# 1. Load data
# 2. Create Freud RDF object
# 3. Compute the RDF
# 4. Extract data from the Freud RDF object
# 5. (optional) Plot data
#
# # Required Packages
#
# We will use the following python packages, please install with your favorite package manager:
#
# * `bokeh` - plotting
# * `numpy` - general scientific goodness

# %%
from bokeh.io import output_notebook
output_notebook()
from bokeh.plotting import figure, output_file, show
from bokeh.layouts import gridplot
import numpy as np
from freud import parallel, box, density
parallel.setNumThreads(4)

def default_bokeh(p):
    p.title.text_font_size = "18pt"
    p.title.align = "center"

    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"

    p.xaxis.major_tick_in = 10
    p.xaxis.major_tick_out = 0
    p.xaxis.minor_tick_in = 5
    p.xaxis.minor_tick_out = 0

    p.yaxis.major_tick_in = 10
    p.yaxis.major_tick_out = 0
    p.yaxis.minor_tick_in = 5
    p.yaxis.minor_tick_out = 0

    p.xaxis.major_label_text_font_size = "12pt"
    p.yaxis.major_label_text_font_size = "12pt"
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cf92c54b-a44d-46c1-8f66-63b42a8b5e13">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Set Up Freud
#
# Now we need to import freud to our environment. In this case, we will import specific modules rather than import the whole of freud. Feel free to just use
#
#     import freud
#
# as you see fit.

# %%
from freud import parallel, box, density
parallel.setNumThreads(4)

# %% [markdown]
# We imported the following modules:
#
# * parallel - allows you to set the number of threads you will use during calculations. Yes, Freud is parallelized!
#     - By default freud will use the maximum number of threads available on your machine. Here, I set it to 4, please set as needed on your machine. If working on a shared machine, consider using a moderate number of threads.
#     - Don't forget to benchmark your calculations, or refer to the freud benchmarks to determine the optimal number of cores to use. More is not always better!
# * box - module used to create the simulation boxes used in freud calculations
# * density - module containing density-related calculations, including the radial distribution function

# %% [markdown]
# # Loading Data
#
# Freud makes no assumptions about your data, and doesn't provide a method to load specified formats, everything passed into freud must be a `np.ndarray` of type required by freud (see documentation). In this example numpy binary files containing data are used.
#
# # Create the RDF Object
#
# Each module in Freud contains a number of available computations. In order to perform any computations, you need to create an instance of the object. Please refer to the documentation for what arguments need to be supplied for the compute module you wish to use.
#
# Let's create the RDF object. For your convenience, we use the help function to show what needs to be supplied:

# %%
help(density.RDF)
# Out:
# Help on class RDF in module freud._freud:
#
# class RDF(builtins.object)
#  |  Computes RDF for supplied data
#  |
#  |  The RDF (:math:`g \left( r \right)`) is computed and averaged for a given set of reference points in a sea of     data points. Providing the same points calculates them against themselves. Computing the RDF results in an rdf     array listing the value of the RDF at each given :math:`r`, listed in the r array.
#  |
#  |  The values of :math:`r` to compute the rdf are set by the values of rmax, dr in the constructor. rmax sets the maximum
#  |  distance at which to calculate the :math:`g \left( r \right)` while dr determines the step size for each bin.
#  |
#  |  .. moduleauthor:: Eric Harper <harperic@umich.edu>
#  |
#  |  .. note::
#  |      2D: RDF properly handles 2D boxes. Requires the points to be passed in [x, y, 0]. Failing to z=0 will lead to         undefined behavior.
#  |
#  |  :param rmax: maximum distance to calculate
#  |  :param dr: distance between histogram bins
#  |  :type rmax: float
#  |  :type dr: float
#  |
#  |  Methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  accumulate(...)
#  |      RDF.accumulate(self, box, ndarray ref_points, ndarray points)
#  |
#  |      Calculates the rdf and adds to the current rdf histogram.
#  |
#  |      :param box: simulation box
#  |      :param ref_points: reference points to calculate the local density
#  |      :param points: points to calculate the local density
#  |      :type box: :py:class:`freud.box.Box`
#  |      :type ref_points: :class:`numpy.ndarray`, shape=(:math:`N_{particles}`, 3), dtype= :class:`numpy.float32`
#  |      :type points: :class:`numpy.ndarray`, shape=(:math:`N_{particles}`, 3), dtype= :class:`numpy.float32`
#  |
#  |  compute(...)
#  |      RDF.compute(self, box, ndarray ref_points, ndarray points)
#  |
#  |      Calculates the rdf for the specified points. Will overwrite the current histogram.
#  |
#  |      :param box: simulation box
#  |      :param ref_points: reference points to calculate the local density
#  |      :param points: points to calculate the local density
#  |      :type box: :py:meth:`freud.box.Box`
#  |      :type ref_points: :class:`numpy.ndarray`, shape=(:math:`N_{particles}`, 3), dtype= :class:`numpy.float32`
#  |      :type points: :class:`numpy.ndarray`, shape=(:math:`N_{particles}`, 3), dtype= :class:`numpy.float32`
#  |
#  |  getBox(...)
#  |      RDF.getBox(self)
#  |
#  |      :return: Freud Box
#  |      :rtype: :py:class:`freud.box.Box`
#  |
#  |  getNr(...)
#  |      RDF.getNr(self)
#  |
#  |      :return: histogram of cumulative rdf values
#  |      :rtype: :class:`numpy.ndarray`, shape=(:math:`N_{bins}`, 3), dtype= :class:`numpy.float32`
#  |
#  |  getR(...)
#  |      RDF.getR(self)
#  |
#  |      :return: values of the histogram bin centers
#  |      :rtype: :class:`numpy.ndarray`, shape=(:math:`N_{bins}`, 3), dtype= :class:`numpy.float32`
#  |
#  |  getRDF(...)
#  |      RDF.getRDF(self)
#  |
#  |      :return: histogram of rdf values
#  |      :rtype: :class:`numpy.ndarray`, shape=(:math:`N_{bins}`, 3), dtype= :class:`numpy.float32`
#  |
#  |  reduceRDF(...)
#  |      RDF.reduceRDF(self)
#  |
#  |      Reduces the histogram in the values over N processors to a single histogram. This is called automatically by
#  |      :py:meth:`freud.density.RDF.getRDF()`, :py:meth:`freud.density.RDF.getNr()`.
#  |
#  |  resetRDF(...)
#  |      RDF.resetRDF(self)
#  |
#  |      resets the values of RDF in memory

# %% [markdown]
# It looks like the constructor takes in `rmax` and `dr` as parameters, or the maximum distance to calculate the rdf, and the size of the rdf histogram bin e.g. `r_max = 10` and `dr = 0.1`:

# %%
rdf = density.RDF(rmax=10.0, dr=0.1)

# %% [markdown]
# # Compute the RDF
#
# It's time to actually compute the rdf, so here we go, what is happening is briefly explained in the comments

# %%
data_path = "ex_data/phi065"
box_data = np.load("{}/box_data.npy".format(data_path))
pos_data = np.load("{}/pos_data.npy".format(data_path))
n_frames = pos_data.shape[0]

# compute the rdf for the last frame
# read box, position data
l_box = box_data[-1]
l_pos = pos_data[-1]
# create the freud box object
fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
# compute
rdf.compute(fbox, l_pos, l_pos)

# %% [markdown]
# # I computed the RDF, now what?
#
# You might be thinking to yourself "ok, now what?" First, you need to get your data out of freud. Second, you need to visualize that data.

# %% [markdown]
# ## Getting your data out of Freud
#
# That sweet, sweet RDF data is currently in C++, but we want it in python, so let's get it out of there!

# %%
# get the center of the histogram bins
r = rdf.getR()
# get the value of the histogram bins
y = rdf.getRDF()

# %% [markdown]
# ## Visualizing your data
#
# Remember, Freud makes no assumptions about your data or how you want to visualize it. Want to use matplotlib like we do here? Go right ahead. Want to be a heathen and use Excel? Go right ahead, no one is stopping you (except your conscience...don't use Excel)

# %%
# create bokeh plot
p = figure(title="RDF", x_axis_label='r', y_axis_label='g(r)')
p.line(r, y, legend="g(r)", line_width=2)
default_bokeh(p)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bcc09696-f82a-46c8-86fb-7d78d03245c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bcc09696-f82a-46c8-86fb-7d78d03245c8").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bcc09696-f82a-46c8-86fb-7d78d03245c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bcc09696-f82a-46c8-86fb-7d78d03245c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"819e98d0-1f02-409c-8d90-8e1211760f77":{"roots":{"references":[{"attributes":{"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"}},"id":"cca846fa-41de-40af-88bb-03365cb34764","type":"HelpTool"},{"attributes":{"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"}},"id":"ed85e295-916e-4d45-b710-b27273a50165","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[100]},"y":{"__ndarray__":"...","dtype":"float32","shape":[100]}}},"id":"0ee65367-33dc-42be-a7f1-e84320ba47f3","type":"ColumnDataSource"},{"attributes":{},"id":"3349832e-1594-4132-b7a2-7cc6a22d834a","type":"BasicTicker"},{"attributes":{"callback":null},"id":"ca1b8674-2b83-49cd-98c9-934e90313892","type":"DataRange1d"},{"attributes":{"data_source":{"id":"0ee65367-33dc-42be-a7f1-e84320ba47f3","type":"ColumnDataSource"},"glyph":{"id":"0c4fba7d-bab4-4b77-9752-c3eed7a8a2e8","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"5623b59d-c7f0-4436-9370-bd1b944cb335","type":"Line"},"selection_glyph":null},"id":"7ae687ce-87af-4b1c-a1b1-3da98acaea80","type":"GlyphRenderer"},{"attributes":{"items":[{"id":"ad6cff56-3915-4505-b682-a5581124cacb","type":"LegendItem"}],"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"}},"id":"493078cc-5733-4d31-adb2-78daabc042c0","type":"Legend"},{"attributes":{"axis_label":"g(r)","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"ae62c18f-5ac2-469e-8d2c-ffdb2873f111","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"},"ticker":{"id":"3349832e-1594-4132-b7a2-7cc6a22d834a","type":"BasicTicker"}},"id":"7e6c625c-e0b0-4136-8a25-6ff84e9f66e7","type":"LinearAxis"},{"attributes":{"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"}},"id":"c38df1f0-ffda-42dc-bb6b-99d9a354140f","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"},"ticker":{"id":"3349832e-1594-4132-b7a2-7cc6a22d834a","type":"BasicTicker"}},"id":"47754e30-aae7-4028-9d51-ce3693f4fbbf","type":"Grid"},{"attributes":{"callback":null},"id":"4a10b4e4-4d95-48f7-83b3-458d6068f3a4","type":"DataRange1d"},{"attributes":{"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"}},"id":"a458ab35-488f-4d1c-93f7-8b7c596e8fba","type":"ResetTool"},{"attributes":{"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"}},"id":"3193c527-96ab-471b-84d5-f1228b06d763","type":"PanTool"},{"attributes":{"axis_label":"r","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"277d3417-b343-40e5-86b3-d9c572ac39b1","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"79149a6a-c803-40ca-9068-24185d1baa7f","subtype":"Figure","type":"Plot"},"ticker":{"id":"e83c7185-fc59-4aa2-8ae1-3156b9c31677","type":"BasicTicker"}},"id":"76f9ebe6-1377-4460-96fe-c99c8f73ab65","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c4fba7d-bab4-4b77-9752-c3eed7a8a2e8","type":"Line"},{"attributes":{},"id":"a926e1a9-2f3e-4217-94f6-2085c06426c6","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3193c527-96ab-471b-84d5-f1228b06d763","type":"PanTool"},{"id":"ed85e295-916e-4d45-b710-b27273a50165","type":"WheelZoomTool"},{"id":"2480f055-d7d6-405b-9af7-3466a40cd48c","type":"BoxZoomTool"},{"id":"c38df1f0-ffda-42dc-bb6b-99d9a354140f","type":"SaveTool"},{"id":"a458ab35-488f-4d1c-93f7-8b7c596e8fba","type":"ResetTool"},{ ...

# %% [markdown]
# # Accumulate, or how I stopped worrying and let Freud do trivial tasks for me
#
# A lot of times we want to average our data over many simualtion frames. Freud does this for you with the `accumulate` method:

# %%
data_path = "ex_data/phi065"
box_data = np.load("{}/box_data.npy".format(data_path))
pos_data = np.load("{}/pos_data.npy".format(data_path))
n_frames = pos_data.shape[0]

# compute the rdf for for all frames except the first (your syntax will vary based on your reader)
for i in range(1, n_frames):
    # read box, position data
    l_box = box_data[i]
    l_pos = pos_data[i]
    # create the freud box object
    fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
    # accumulate
    rdf.accumulate(fbox, l_pos, l_pos)

# get the center of the histogram bins
r = rdf.getR()
# get the value of the histogram bins
y = rdf.getRDF()
# create bokeh figure
p = figure(title="RDF", x_axis_label='r', y_axis_label='g(r)')
p.circle(r, y, legend="g(r)", line_width=2)
p.line(r, y, legend="g(r)", line_width=2)
default_bokeh(p)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d8e9da06-50a3-446d-bc95-1bdd60a2233f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d8e9da06-50a3-446d-bc95-1bdd60a2233f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d8e9da06-50a3-446d-bc95-1bdd60a2233f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd8e9da06-50a3-446d-bc95-1bdd60a2233f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"086f9d23-0942-43cc-9103-3c123b5e6572":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d03add9-50fb-4d7f-8af4-8e84cd0e98d3","type":"Circle"},{"attributes":{"below":[{"id":"6d86e3c9-078a-4e04-bdb6-483fa0f61327","type":"LinearAxis"}],"left":[{"id":"60ada8ef-5a1d-42f5-9304-3471ff7bdee1","type":"LinearAxis"}],"renderers":[{"id":"6d86e3c9-078a-4e04-bdb6-483fa0f61327","type":"LinearAxis"},{"id":"1a18727c-70cf-4340-8ba0-ecd6017bbd53","type":"Grid"},{"id":"60ada8ef-5a1d-42f5-9304-3471ff7bdee1","type":"LinearAxis"},{"id":"8f607ec1-94e4-480c-92a5-7930ade59db4","type":"Grid"},{"id":"c51da096-7e78-4d44-8b07-b35380a8b9d5","type":"BoxAnnotation"},{"id":"9dfcbcb0-e46b-4710-9f41-b28059dfec72","type":"Legend"},{"id":"3aba1a6d-82e1-437c-b4eb-ab74294e043d","type":"GlyphRenderer"},{"id":"3b8ff702-0dca-4798-be46-96f9dcc08e37","type":"GlyphRenderer"}],"title":{"id":"5551e13b-ddef-46c3-8f62-849dba4bbdbe","type":"Title"},"tool_events":{"id":"22c7496d-116f-462e-848e-4da41e4c9788","type":"ToolEvents"},"toolbar":{"id":"95c8c4a1-8279-4257-9721-cbd63c620a06","type":"Toolbar"},"x_range":{"id":"ac34dc64-6982-4a6a-a08d-2665e0403600","type":"DataRange1d"},"y_range":{"id":"343343cf-f718-409b-bcc5-970a8ce74197","type":"DataRange1d"}},"id":"cbcb962c-bf55-4fed-a2cb-5368128e5741","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"g(r)"},"renderers":[{"id":"3aba1a6d-82e1-437c-b4eb-ab74294e043d","type":"GlyphRenderer"},{"id":"3b8ff702-0dca-4798-be46-96f9dcc08e37","type":"GlyphRenderer"}]},"id":"74bff457-234e-4849-a741-ccf46679eade","type":"LegendItem"},{"attributes":{"plot":{"id":"cbcb962c-bf55-4fed-a2cb-5368128e5741","subtype":"Figure","type":"Plot"}},"id":"99c3dc0f-32b3-4c4d-ac23-221266694ced","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"cbcb962c-bf55-4fed-a2cb-5368128e5741","subtype":"Figure","type":"Plot"}},"id":"b7ee9bc4-f5f2-498f-b1b4-fb17728ef1aa","type":"HelpTool"},{"attributes":{"plot":{"id":"cbcb962c-bf55-4fed-a2cb-5368128e5741","subtype":"Figure","type":"Plot"}},"id":"051b8739-e104-4fed-94e1-22329ef31ce1","type":"PanTool"},{"attributes":{"align":"center","plot":null,"text":"RDF","text_font_size":{"value":"18pt"}},"id":"5551e13b-ddef-46c3-8f62-849dba4bbdbe","type":"Title"},{"attributes":{"axis_label":"r","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"0560e65c-6c41-4c09-bc81-6870a43e0fb5","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"cbcb962c-bf55-4fed-a2cb-5368128e5741","subtype":"Figure","type":"Plot"},"ticker":{"id":"6cceb568-7c83-4a3e-84c9-34e9e0aaf0fc","type":"BasicTicker"}},"id":"6d86e3c9-078a-4e04-bdb6-483fa0f61327","type":"LinearAxis"},{"attributes":{},"id":"6cceb568-7c83-4a3e-84c9-34e9e0aaf0fc","type":"BasicTicker"},{"attributes":{"callback":null},"id":"ac34dc64-6982-4a6a-a08d-2665e0403600","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"051b8739-e104-4fed-94e1-22329ef31ce1","type":"PanTool"},{"id":"99c3dc0f-32b3-4c4d-ac23-221266694ced","type":"WheelZoomTool"},{"id":"71533e7b-e1b3-4483-92bc-c25d04deb4d4","type":"BoxZoomTool"},{"id":"02d2c26f-3536-4f6d-a3ab-ba3d7943c5bb","type":"SaveTool"},{"id":"2707fc49-5deb-4262-9d6f-576886e70a96","type":"ResetTool"},{"id":"b7ee9bc4-f5f2-498f-b1b4-fb17728ef1aa","type":"HelpTool"}]},"id":"95c8c4a1-8279-4257-9721-cbd63c620a06","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"cbcb962c-bf55-4fed-a2cb-5368128e5741","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d062fbe-6f2b-4731-9578-364d72bb17dd","type":"BasicTicker"}},"id":"8f607ec1-94e4-480c-92a5-7930ade59db4","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alph ...

# %% [markdown]
# # What's the difference?
#
# Let's plot together and find out:

# %%
# reset the rdf; required if not using compute
rdf.resetRDF()
# compute the rdf for for all frames except the first (your syntax will vary based on your reader)
for i in range(1, n_frames):
    # read box, position data
    l_box = box_data[i]
    l_pos = pos_data[i]
    # create the freud box object
    fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
    # accumulate
    rdf.accumulate(fbox, l_pos, l_pos)

# get the center of the histogram bins
r_avg = rdf.getR()
# get the value of the histogram bins
y_avg = rdf.getRDF()

# compute the rdf for the last frame
# read box, position data
l_box = box_data[-1]
l_pos = pos_data[-1]
# create the freud box object
fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
# compute
rdf.compute(fbox, l_pos, l_pos)
# get the center of the histogram bins
r = rdf.getR()
# get the value of the histogram bins
y = rdf.getRDF()
# create bokeh plot
p0 = figure(title="RDF", x_axis_label='r', y_axis_label='g(r)')
p0.circle(r, y, legend="Compute")
p0.line(r, y, legend="Compute", line_width=2)
p0.square(r_avg, y_avg, legend="Accumulate", fill_color=None, line_color="red")
p0.line(r_avg, y_avg, legend="Accumulate", line_dash=[4,4], line_width=2, line_color="red")

default_bokeh(p0)

p1 = figure(title="RDF", x_axis_label='r', y_axis_label='g(r)')
p1.line(r, y, legend="Compute", line_width=2)
p1.line(r_avg, y_avg, legend="Accumulate", line_width=2, line_color="red")

default_bokeh(p1)

grid = gridplot([p0, p1], ncols=2, plot_width=400, plot_height=400)

show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ce399a7f-413f-4d2e-a851-06d9318a9e79"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ce399a7f-413f-4d2e-a851-06d9318a9e79").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ce399a7f-413f-4d2e-a851-06d9318a9e79");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ce399a7f-413f-4d2e-a851-06d9318a9e79' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"909c73b6-d736-412c-9944-225e1dd51ef1":{"roots":{"references":[{"attributes":{"plot":{"id":"f07e0466-89fd-4d1e-90b5-7b4f9fc7b2c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"3d5f07ea-eb87-444c-8126-daf6ce0f7a4e","type":"BasicTicker"}},"id":"f231dcba-736b-4a46-8e7d-2c4aaeec2920","type":"Grid"},{"attributes":{"fill_color":{"value":null},"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f52db44b-b473-44fa-bebc-275b0b45a13a","type":"Square"},{"attributes":{},"id":"6df3367e-8172-4854-af2f-f423b7c94e6e","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"96659de7-0b34-450b-b1a2-c9621b25ee61","type":"ColumnDataSource"},"glyph":{"id":"3de7a156-a239-418d-914a-6d22e7274a4f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"065983c4-2db1-4473-a26a-49300afdc419","type":"Line"},"selection_glyph":null},"id":"65d1ae48-9ea4-45bd-b37e-a3abab93a8ab","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e8f0631a-0a56-4773-8a4d-5b685546eb0c","type":"ColumnDataSource"},"glyph":{"id":"f52db44b-b473-44fa-bebc-275b0b45a13a","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"a342d90d-e1a2-4810-821c-37ae41605b43","type":"Square"},"selection_glyph":null},"id":"5d839ce3-51cc-4f9d-8f72-378353871f88","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"85a32340-2f1d-4484-a6e4-056a0e93c1b0","type":"DataRange1d"},{"attributes":{"callback":null},"id":"99699c67-fd38-4a62-a767-ef5318e43083","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d190e7f-7104-42f7-a50a-184d8798c0fd","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e6acb88d-cc27-41d3-9c48-2667d3b38661","type":"Circle"},{"attributes":{"align":"center","plot":null,"text":"RDF","text_font_size":{"value":"18pt"}},"id":"a6740b88-1d73-4c42-9c42-3ae117dd55ec","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[100]},"y":{"__ndarray__":"...","dtype":"float32","shape":[100]}}},"id":"e8f0631a-0a56-4773-8a4d-5b685546eb0c","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"f07e0466-89fd-4d1e-90b5-7b4f9fc7b2c4","subtype":"Figure","type":"Plot"}},"id":"71ff1e0b-e543-43b1-8478-6f9ab79b5bc9","type":"PanTool"},{"attributes":{"data_source":{"id":"513ea518-2d25-4642-8423-3923a80b763c","type":"ColumnDataSource"},"glyph":{"id":"c396612b-2a22-4fbb-a891-d34708920f00","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0d190e7f-7104-42f7-a50a-184d8798c0fd","type":"Line"},"selection_glyph":null},"id":"24e0ef4b-f9bd-4718-8b7e-baf1b8dd11f9","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"f07e0466-89fd-4d1e-90b5-7b4f9fc7b2c4","subtype":"Figure","type":"Plot"}},"id":"eeafad35-c9ee-4f7d-b63f-fefa1a21893d","type":"HelpTool"},{"attributes":{"label":{"value":"Accumulate"},"renderers":[{"id":"5d839ce3-51cc-4f9d-8f72-378353871f88","type":"GlyphRenderer"},{"id":"a0daac68-ddb5-42f6-b5a4-c69c8d24292b","type":"GlyphRenderer"}]},"id":"8f2cc8ac-ca6b-42a9-bd34-1fc9f48968b2","type":"LegendItem"},{"attributes":{"data_source":{"id":"986be085-3a0d-4219-9224-8b64902b3a38","type":"ColumnDataSource"},"glyph":{"id":"d143d6a4-ba74-416a-958e-ae7cf332e266","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0e91d543-c31b-49cb-a0f8-fab6590e9771","type":"Line"},"selection_glyph":null},"id":"a0daac68-ddb5-42f6-b5a4-c69c8d24292b","type":"GlyphRenderer"},{"attributes":{},"id":"3d5f07ea-eb87-444c-8126-daf6ce0f7a4e","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[100]},"y":{"__ndarray__":"...","dtype":"float32","shape":[100]}}},"id":"513ea518-2d25-4642-8423-3923a80b763c","type":"ColumnDataSource"},{"at ...

# %% [markdown]
# # Wait a second, there's no difference?!
#
# Right you are, but there should be...

# %%
# reset the rdf; required if not using compute
rdf.resetRDF()
# compute the rdf for for all frames except the first (your syntax will vary based on your reader)
for i in range(1, n_frames):
    # read box, position data
    l_box = box_data[i]
    l_pos = pos_data[i]
    # create the freud box object
    fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
    # accumulate
    rdf.accumulate(fbox, l_pos, l_pos)

# USE NP.COPY!
# get the center of the histogram bins
r_avg = np.copy(rdf.getR())
# get the value of the histogram bins
y_avg = np.copy(rdf.getRDF())

# compute the rdf for the last frame
# read box, position data
l_box = box_data[-1]
l_pos = pos_data[-1]
# create the freud box object
fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
# compute
rdf.compute(fbox, l_pos, l_pos)
# get the center of the histogram bins
r = rdf.getR()
# get the value of the histogram bins
y = rdf.getRDF()
# create bokeh plot
p0 = figure(title="RDF", x_axis_label='r', y_axis_label='g(r)')
p0.circle(r, y, legend="Compute")
p0.line(r, y, legend="Compute", line_width=2)
p0.square(r_avg, y_avg, legend="Accumulate", fill_color=None, line_color="red")
p0.line(r_avg, y_avg, legend="Accumulate", line_dash=[4,4], line_width=2, line_color="red")

default_bokeh(p0)

p1 = figure(title="RDF", x_axis_label='r', y_axis_label='g(r)')
p1.line(r, y, legend="Compute", line_width=2)
p1.line(r_avg, y_avg, legend="Accumulate", line_width=2, line_color="red")

default_bokeh(p1)

grid = gridplot([p0, p1], ncols=2, plot_width=400, plot_height=400)

show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d4a43bc9-4708-4b76-bd99-f33100025abf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d4a43bc9-4708-4b76-bd99-f33100025abf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d4a43bc9-4708-4b76-bd99-f33100025abf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd4a43bc9-4708-4b76-bd99-f33100025abf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6d09271e-5e99-4727-b417-99fde3022152":{"roots":{"references":[{"attributes":{"plot":{"id":"4aab3707-cd37-4a78-ade3-017ec0f5d526","subtype":"Figure","type":"Plot"}},"id":"f8a0ea38-b310-45b9-a9bb-ef20a7f08d63","type":"SaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"007bdcd7-8f92-4778-bd36-a1ab672f4cad","type":"Line"},{"attributes":{"callback":null},"id":"985416e0-2773-4be6-851d-af03ac1f98cc","type":"DataRange1d"},{"attributes":{"plot":{"id":"e4bd6738-687a-4f86-88e4-a291828a0a32","subtype":"Figure","type":"Plot"}},"id":"96d4f3dd-fa4a-4a8f-b5e4-eb3bf33cfeec","type":"PanTool"},{"attributes":{"axis_label":"r","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"d13a40da-0798-4d08-b003-69d1e9471ec3","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"4aab3707-cd37-4a78-ade3-017ec0f5d526","subtype":"Figure","type":"Plot"},"ticker":{"id":"a63e3c1d-fcd2-45c3-ab08-0451f7280cae","type":"BasicTicker"}},"id":"0da5a4f9-09b8-480a-ba33-5467f48efb7a","type":"LinearAxis"},{"attributes":{"plot":{"id":"e4bd6738-687a-4f86-88e4-a291828a0a32","subtype":"Figure","type":"Plot"}},"id":"416ccdb8-1071-4556-8e53-3b89a36a4c34","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"96d4f3dd-fa4a-4a8f-b5e4-eb3bf33cfeec","type":"PanTool"},{"id":"c6034288-20e3-4e42-8fd8-582ecfe205af","type":"WheelZoomTool"},{"id":"5491e20a-e711-45a8-86c0-2e05bb5b5a9e","type":"BoxZoomTool"},{"id":"47f2e091-e1da-4457-8f2f-ebad090c2dba","type":"SaveTool"},{"id":"416ccdb8-1071-4556-8e53-3b89a36a4c34","type":"ResetTool"},{"id":"f18591ee-f8e7-4378-b6a1-202940711c5c","type":"HelpTool"}]},"id":"40b05546-5c38-43eb-8c01-ff06a9178600","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"e4bd6738-687a-4f86-88e4-a291828a0a32","subtype":"Figure","type":"Plot"},"ticker":{"id":"9fd37584-cb1c-4ae2-9eab-a3a4af977eb4","type":"BasicTicker"}},"id":"1e4dca39-396c-437b-8ec5-03c233340f38","type":"Grid"},{"attributes":{"data_source":{"id":"ed5955cf-e856-497b-ae54-2eac66b67a9c","type":"ColumnDataSource"},"glyph":{"id":"92b974c9-5cf3-4143-84b0-7b4ab705c334","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b43e3ae3-6781-44ef-b6da-570c17c1a782","type":"Line"},"selection_glyph":null},"id":"dcb02465-89db-4d82-838a-9b3cd938a707","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"4aab3707-cd37-4a78-ade3-017ec0f5d526","subtype":"Figure","type":"Plot"},"ticker":{"id":"50e05327-389a-45b4-a390-2309bed8de01","type":"BasicTicker"}},"id":"13014433-ae85-4532-94ce-86f1a2b1a900","type":"Grid"},{"attributes":{"data_source":{"id":"d48988b5-872b-40d5-a23e-192732f4dade","type":"ColumnDataSource"},"glyph":{"id":"7f31e519-31f7-43b4-9895-6413bf902c46","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"1a1f30f2-f46a-4572-9364-668998bc4c37","type":"Square"},"selection_glyph":null},"id":"e08474bb-14f9-44d5-92c4-a726afd02c31","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b43e3ae3-6781-44ef-b6da-570c17c1a782","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a1f30f2-f46a-4572-9364-668998bc4c37","type":"Square"},{"attributes":{"below":[{"id":"00393a0c-4be3-4feb-8d57-f2d8424da946","type":"LinearAxis"}],"left":[{"id":"44339c6c-d33f-4b86-9517-a4f9d7b2bb3e","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"00393a0c-4be3-4feb-8d57-f2d8424da946","type":"LinearAxis"},{"id":"057c2a6c-1c20-4734-9557-77186ba97836","type":"Grid"},{"id":"44339c6c-d33f-4b86-9517-a4f9d7b2bb3e","type":"LinearAxis"}, ...

# %% [markdown]
# # Pointers vs. Copies
#
# By default Freud returns a NumPy array *as a pointer*. This is done for speed, but can result in the above problem. Please be sure to copy your data out as needed. A more in-depth discussion can be found in the [NumPy arrays from pointers example notebook](CopyVsPointers.ipynb).
