# %% [markdown]
# *Datasets used in this example are a system of hard hexagons, simulated in the NVT thermodynamic ensemble in HOOMD-Blue, for a dense fluid (phi065) and a solid (phi075)*

# %%
from bokeh.io import output_notebook
output_notebook()
from bokeh.plotting import figure, output_file, show
from bokeh.layouts import gridplot
import numpy as np
import time
from freud import parallel
parallel.setNumThreads(4)

def default_bokeh(p):
    """
    wrapper which takes the default bokeh outputs and changes them to more sensible values
    """
    p.title.text_font_size = "18pt"
    p.title.align = "center"

    p.xaxis.axis_label_text_font_size = "14pt"
    p.yaxis.axis_label_text_font_size = "14pt"

    p.xaxis.major_tick_in = 10
    p.xaxis.major_tick_out = 0
    p.xaxis.minor_tick_in = 5
    p.xaxis.minor_tick_out = 0

    p.yaxis.major_tick_in = 10
    p.yaxis.major_tick_out = 0
    p.yaxis.minor_tick_in = 5
    p.yaxis.minor_tick_out = 0

    p.xaxis.major_label_text_font_size = "12pt"
    p.yaxis.major_label_text_font_size = "12pt"

def cubeellipse(theta, lam=0.5, gamma=1., s=4.0, r=1., h=1.):
    """Create an RGB colormap from an input angle theta. Takes lam (a list of
    intensity values, from 0 to 1), gamma (a nonlinear weighting power),
    s (starting angle), r (number of revolutions around the circle), and
    h (a hue factor)."""
    import numpy
    lam = lam**gamma

    a = h*lam*(1 - lam)*.5
    v = numpy.array([[-.14861, 1.78277], [-.29227, -.90649], [1.97294, 0.]], dtype=numpy.float32)
    ctarray = numpy.array([numpy.cos(theta*r + s), numpy.sin(theta*r + s)], dtype=numpy.float32)
    # convert to 255 rgb
    ctarray = (lam + a*v.dot(ctarray)).T
    ctarray *= 255
    ctarray = ctarray.astype(dtype=np.int32)
    return ctarray

def local_to_global(verts, positions, orientations):
    """
    Take a list of vertices, positions, and orientations and create
    a list of vertices in the "global coordinate system" for plotting
    in bokeh
    """
    num_particles = len(positions)
    num_verts = len(verts)
    # create list of vertices in the "local reference frame" i.e.
    # centered at (0,0)
    l_verts = np.zeros(shape=(num_particles, num_verts, 2), dtype=np.float32)
    l_verts[:] = verts
    # create array of rotation matrices
    rot_mat = np.zeros(shape=(num_particles, 2, 2), dtype=np.float32)
    for i, theta in enumerate(orientations):
        rot_mat[i] = [[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]]
    # rotate; uses einsum for speed; please see numpy documentation
    # for more information
    r_verts = np.einsum("lij,lkj->lki", rot_mat, l_verts)
    # now translate to global coordinates
    # need to create a position array with same shape as vertex array
    l_pos = np.zeros(shape=(num_particles, num_verts, 2), dtype=np.float32)
    for i in range(num_particles):
        for j in range(len(verts)):
            l_pos[i,j] = positions[i]
    # translate
    output_array = np.add(r_verts, l_pos)
    return output_array

def clamp(x):
    """
    limit values between 0 and 255
    http://stackoverflow.com/questions/3380726/converting-a-rgb-color-tuple-to-a-six-digit-code-in-python
    """
    return max(0, min(x, 255))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="73078947-a90d-4c5d-9749-ecc6187e3f74">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Nearest Neighbors
#
# One of the basic computations required for higher-level computations (such as the [hexatic order parameter](AIChE Hexatic.ipynb)) is finding the nearest neighbors of a particle. This tutorial will show you how to compute the nearest neighbors and visualize that data.
#
# The algorithm is straightforward:
#
# ~~~
# for each particle i:
#     for each particle j in neighbor_cells(i):
#         r_ij = position[j] - position[i]
#         r = sqrt(dot(r_ij, r_ij))
#         l_r_array.append(r)
#         l_n_array.append(j)
#         # sort by distance
#         sort(n_array, r_array)
#         neighbor_array[i] = n_array[:k]
# ~~~

# %%
# import the box and locality modules;
# Nearest Neighbors calculation is provided by the locality module
from freud import box, locality
# load the data
data_path = "ex_data/phi065"
box_data = np.load("{}/box_data.npy".format(data_path))
pos_data = np.load("{}/pos_data.npy".format(data_path))
quat_data = np.load("{}/quat_data.npy".format(data_path))
n_frames = pos_data.shape[0]

# %% [markdown]
# ## The Nearest Neighbor object
#
# This module will give the indices of the \\(k\\) particles which are nearest to another particle. Freud provides two different modes by which to compute the nearest neighbors, selected by the `strict_cut` variable:
#
# * `strict_cut=False` (*default*): The value for `rmax` is expanded until every particle has \\(k\\) nearest neighbors
# * `strict_cut=True`: the `rmax` value is not expanded, so that any "vacancies" in the number of neighbors found are filled with `UINTMAX`
#
# ### `strict_cut=False`
#
# First we show how to use the `strict_cut=False` mode to find the neighbors of a specific particle

# %%
# create freud nearest neighbor object
# set number of neighbors
n_neigh = 6
# create freud nearest neighbors object
nn = locality.NearestNeighbors(rmax=1.5,n_neigh=n_neigh,strict_cut=False)
# grab data from last frame
l_box = box_data[-1]
l_pos = pos_data[-1]
l_quat = quat_data[-1]
l_ang = 2*np.arctan2(np.copy(l_quat[:,3]), np.copy(l_quat[:,0]))

# create box
fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
side_length = max(fbox.Lx, fbox.Ly)
l_min = -side_length / 2.0
l_max = -l_min

# compute nearest neighbors for 6 nearest neighbors
start_time = time.time()
nn.compute(fbox, l_pos, l_pos)
stop_time = time.time()
print("time to calc 1 frame = {}".format(stop_time-start_time))
# get the neighborlist
n_list = nn.getNeighborList()
# get the number of particles
num_particles = nn.getNRef()
# get the neighbors for particle 0
pidx = 0
n_idxs = n_list[pidx]
# create a list of positions, angles to draw
draw_pos = np.zeros(shape=(n_neigh+1, 3),dtype=np.float32)
draw_pos[0] = l_pos[pidx]
draw_pos[1:] = l_pos[n_idxs]
draw_ang = np.zeros(shape=(n_neigh+1),dtype=np.float32)
draw_ang[0] = l_ang[pidx]
draw_ang[1:] = l_ang[n_idxs]

# render in bokeh
# vertex positions for hexagons
verts = [[0.537284965911771, 0.31020161970069976],
         [3.7988742065678664e-17, 0.6204032394013997],
         [-0.5372849659117709, 0.31020161970070004],
         [-0.5372849659117711, -0.31020161970069976],
         [-1.1396622619703597e-16, -0.6204032394013997],
         [0.5372849659117711, -0.3102016197006997]]
verts = np.array(verts)
# create array of transformed positions
patches = local_to_global(verts, draw_pos[:,0:2], draw_ang)
# turn into list of colors
c_list = ["#30A2DA", "#FC4F30", "#E5AE38", "#6D904F", "#9757DB",
    "#188487", "#FF7F00", "#9A2C66", "#626DDA", "#8B8B8B"]
# bokeh (as of this version) requires hex colors, so convert rgb to hex
# draw neighbors orange
hex_color = [c_list[1] for _ in range(n_neigh+1)]
# draw central particle blue
hex_color[0] = c_list[0]
# plot
p = figure(title="Nearest Neighbors visualization",x_range=(l_min, l_max), y_range=(l_min, l_max))
p.patches(xs=patches[:,:,0].tolist(), ys=patches[:,:,1].tolist(),
    fill_color=hex_color, line_color="black")
# box display
p.patches(xs=[[-fbox.Lx/2, fbox.Lx/2, fbox.Lx/2, -fbox.Lx/2]],
          ys=[[-fbox.Ly/2, -fbox.Ly/2, fbox.Ly/2, fbox.Ly/2]],
          fill_color=(0,0,0,0), line_color="black", line_width=2)
default_bokeh(p)
show(p)

# black magic for quick position to rsq computation
# given an array Np x 3 (x,y,z), find the distance each particle is from the origin
# rsq = np.einsum("ij,ij->i", pos, pos)
# some kind of plotting thing here
# plt.plot(rsq, n_neighbors)
# Out:
# time to calc 1 frame = 0.028339862823486328
#     <div class="bk-root">
#         <div class="plotdiv" id="0ed6e60e-9c2c-417d-87dc-ec21c5bae5cb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0ed6e60e-9c2c-417d-87dc-ec21c5bae5cb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0ed6e60e-9c2c-417d-87dc-ec21c5bae5cb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0ed6e60e-9c2c-417d-87dc-ec21c5bae5cb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9e5c7aa6-9859-46a7-8358-8b100b1bf1d1":{"roots":{"references":[{"attributes":{"plot":{"id":"08a40094-0610-4d19-9e90-ccf9e41af3dc","subtype":"Figure","type":"Plot"}},"id":"57f196cf-9490-4a13-ba04-4a4902f2cb50","type":"SaveTool"},{"attributes":{},"id":"ed60842c-e813-40b4-a76f-771e0cf5ea71","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"08a40094-0610-4d19-9e90-ccf9e41af3dc","subtype":"Figure","type":"Plot"}},"id":"3e74927e-828b-47a4-ae64-6beed98262c7","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"83f8ec24-3d0e-4cd2-942f-c40a9e61f48a","type":"BoxAnnotation"},{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"ed60842c-e813-40b4-a76f-771e0cf5ea71","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"08a40094-0610-4d19-9e90-ccf9e41af3dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"ff062ba1-dc8c-42a6-a549-07f10df6e419","type":"BasicTicker"}},"id":"3e4a79bd-4bdb-47b6-a6e4-c8271b7ee46b","type":"LinearAxis"},{"attributes":{"plot":{"id":"08a40094-0610-4d19-9e90-ccf9e41af3dc","subtype":"Figure","type":"Plot"}},"id":"ec0712a6-1890-4dc7-a35c-c95583529c53","type":"HelpTool"},{"attributes":{},"id":"e458942a-5622-43fe-aec6-e2a4952d0b8d","type":"ToolEvents"},{"attributes":{"align":"center","plot":null,"text":"Nearest Neighbors visualization","text_font_size":{"value":"18pt"}},"id":"f35434ed-cba6-41c0-ac7a-e01e1a279183","type":"Title"},{"attributes":{"overlay":{"id":"83f8ec24-3d0e-4cd2-942f-c40a9e61f48a","type":"BoxAnnotation"},"plot":{"id":"08a40094-0610-4d19-9e90-ccf9e41af3dc","subtype":"Figure","type":"Plot"}},"id":"9f61521a-09df-487f-9438-22817ebda2a6","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"bba275ed-73ae-4137-85a2-02a50411ff46","type":"Patches"},{"attributes":{"plot":{"id":"08a40094-0610-4d19-9e90-ccf9e41af3dc","subtype":"Figure","type":"Plot"}},"id":"182345bb-c03b-425f-9f2d-061f55bb5843","type":"ResetTool"},{"attributes":{"below":[{"id":"6c70032b-3995-4350-8f3d-175a4cd1c746","type":"LinearAxis"}],"left":[{"id":"3e4a79bd-4bdb-47b6-a6e4-c8271b7ee46b","type":"LinearAxis"}],"renderers":[{"id":"6c70032b-3995-4350-8f3d-175a4cd1c746","type":"LinearAxis"},{"id":"dda643c1-454a-49e8-af72-777bd8e1a360","type":"Grid"},{"id":"3e4a79bd-4bdb-47b6-a6e4-c8271b7ee46b","type":"LinearAxis"},{"id":"138a8571-29ee-4266-aa81-70eca39781b8","type":"Grid"},{"id":"83f8ec24-3d0e-4cd2-942f-c40a9e61f48a","type":"BoxAnnotation"},{"id":"df7aaf1a-cd25-429d-ad6a-4d35965e375b","type":"GlyphRenderer"},{"id":"0cb41d19-644c-457e-b690-e6af3bb5ce6e","type":"GlyphRenderer"}],"title":{"id":"f35434ed-cba6-41c0-ac7a-e01e1a279183","type":"Title"},"tool_events":{"id":"e458942a-5622-43fe-aec6-e2a4952d0b8d","type":"ToolEvents"},"toolbar":{"id":"676a523a-9d11-4bf6-bc55-d450012a3fee","type":"Toolbar"},"x_range":{"id":"3ea85eea-6e71-4619-a1b7-bb7d85463e1d","type":"Range1d"},"y_range":{"id":"93681aa0-bbf1-467e-ad40-7bd059d236ac","type":"Range1d"}},"id":"08a40094-0610-4d19-9e90-ccf9e41af3dc","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"6dd86a96-7d3a-494e-933b-6e8898563d97","type":"Patches"},{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"135680cc-930b-4bcd-b0b3-ab2e4008927b","type":"BasicTickFormatter"},"major_label_text_font_size":{"val ...

# %% [markdown]
# Notice that nearest neighbors properly handles periodic boundary conditions
#
# We do the same thing below, but for a particle/neighbors not spanning the box

# %%
# create freud nearest neighbor object
# set number of neighbors
n_neigh = 6
# create freud nearest neighbors object
nn = locality.NearestNeighbors(rmax=1.5,n_neigh=n_neigh,strict_cut=False)
# grab data from last frame
l_box = box_data[-1]
l_pos = pos_data[-1]
l_quat = quat_data[-1]
l_ang = 2*np.arctan2(np.copy(l_quat[:,3]), np.copy(l_quat[:,0]))

# create box
fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
side_length = max(fbox.Lx, fbox.Ly)
l_min = -side_length / 2.0
l_max = -l_min

# compute nearest neighbors for 6 nearest neighbors
start_time = time.time()
nn.compute(fbox, l_pos, l_pos)
stop_time = time.time()
print("time to calc 1 frame = {}".format(stop_time-start_time))
# get the neighborlist
n_list = nn.getNeighborList()
# get the number of particles
num_particles = nn.getNRef()
# get the neighbors for particle 1000
pidx = 1000
n_idxs = n_list[pidx]
# create a list of positions, angles to draw
draw_pos = np.zeros(shape=(n_neigh+1, 3),dtype=np.float32)
draw_pos[0] = l_pos[pidx]
draw_pos[1:] = l_pos[n_idxs]
draw_ang = np.zeros(shape=(n_neigh+1),dtype=np.float32)
draw_ang[0] = l_ang[pidx]
draw_ang[1:] = l_ang[n_idxs]

# render in bokeh
# vertex positions for hexagons
verts = [[0.537284965911771, 0.31020161970069976],
         [3.7988742065678664e-17, 0.6204032394013997],
         [-0.5372849659117709, 0.31020161970070004],
         [-0.5372849659117711, -0.31020161970069976],
         [-1.1396622619703597e-16, -0.6204032394013997],
         [0.5372849659117711, -0.3102016197006997]]
verts = np.array(verts)
# create array of transformed positions
patches = local_to_global(verts, draw_pos[:,0:2], draw_ang)
# turn into list of colors
c_list = ["#30A2DA", "#FC4F30", "#E5AE38", "#6D904F", "#9757DB",
    "#188487", "#FF7F00", "#9A2C66", "#626DDA", "#8B8B8B"]
# bokeh (as of this version) requires hex colors, so convert rgb to hex
# draw neighbors orange
hex_color = [c_list[1] for _ in range(n_neigh+1)]
# draw central particle blue
hex_color[0] = c_list[0]
# plot
p = figure(title="Nearest Neighbors visualization",x_range=(l_min, l_max), y_range=(l_min, l_max))
p.patches(xs=patches[:,:,0].tolist(), ys=patches[:,:,1].tolist(),
    fill_color=hex_color, line_color="black")
# box display
p.patches(xs=[[-fbox.Lx/2, fbox.Lx/2, fbox.Lx/2, -fbox.Lx/2]],
          ys=[[-fbox.Ly/2, -fbox.Ly/2, fbox.Ly/2, fbox.Ly/2]],
          fill_color=(0,0,0,0), line_color="black", line_width=2)
default_bokeh(p)
show(p)

# black magic for quick position to rsq computation
# given an array Np x 3 (x,y,z), find the distance each particle is from the origin
# rsq = np.einsum("ij,ij->i", pos, pos)
# some kind of plotting thing here
# plt.plot(rsq, n_neighbors)
# Out:
# time to calc 1 frame = 0.024489164352416992
#     <div class="bk-root">
#         <div class="plotdiv" id="0cdb692c-7b09-42be-899c-eaf67decb43b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0cdb692c-7b09-42be-899c-eaf67decb43b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0cdb692c-7b09-42be-899c-eaf67decb43b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0cdb692c-7b09-42be-899c-eaf67decb43b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7621e3f2-8096-4d4a-9da1-51c2fd3020c8":{"roots":{"references":[{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"35288a86-3182-47e9-88dc-b297ac3d72b0","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"7ab22a8c-6d2d-4794-a1e7-5389a7c4c244","subtype":"Figure","type":"Plot"},"ticker":{"id":"bfd7d16d-435d-4d2a-80f8-d739cb99fd33","type":"BasicTicker"}},"id":"5b8f684d-eee7-4020-9066-c48d2d77470c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["ys","xs","fill_color"],"data":{"fill_color":["#30A2DA","#FC4F30","#FC4F30","#FC4F30","#FC4F30","#FC4F30","#FC4F30"],"xs":[[-27.493743896484375,-27.44964027404785,-27.963512420654297,-28.52149200439453,-28.565595626831055,-28.05172348022461],[-27.30588150024414,-27.21857452392578,-27.706859588623047,-28.282451629638672,-28.36975860595703,-27.881473541259766],[-28.457826614379883,-27.837495803833008,-27.519149780273438,-27.821134567260742,-28.441465377807617,-28.759811401367188],[-26.53243637084961,-26.199338912963867,-26.486066818237305,-27.105892181396484,-27.438989639282227,-27.15226173400879],[-29.777189254760742,-29.635828018188477,-29.041996002197266,-28.58952522277832,-28.730886459350586,-29.324718475341797],[-26.411026000976562,-26.32183265686035,-26.808937072753906,-27.385238647460938,-27.47443199157715,-26.987327575683594],[-30.34239959716797,-29.74625587463379,-29.299406051635742,-29.448699951171875,-30.044843673706055,-30.4916934967041]],"ys":[[-15.511877059936523,-14.893043518066406,-14.545431137084961,-14.816652297973633,-15.43548583984375,-15.783098220825195],[-16.654193878173828,-16.03996467590332,-15.65723991394043,-15.888744354248047,-16.502973556518555,-16.885698318481445],[-14.512514114379883,-14.521960258483887,-13.989460945129395,-13.447515487670898,-13.438069343566895,-13.970568656921387],[-16.02456283569336,-15.501163482666016,-14.950993537902832,-14.92422103881836,-15.447620391845703,-15.997790336608887],[-15.49365234375,-16.097736358642578,-16.277355194091797,-15.852890014648438,-15.248806953430176,-15.06918716430664],[-14.635784149169922,-14.021825790405273,-13.637601852416992,-13.86733627319336,-14.481294631958008,-14.865518569946289],[-15.223824501037598,-15.395617485046387,-14.965238571166992,-14.363066673278809,-14.19127368927002,-14.621652603149414]]}},"id":"403578e9-0b85-4572-8294-291ba3e74fd0","type":"ColumnDataSource"},{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"035db618-2c3c-48f9-b478-e73fc7cc5cfd","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"7ab22a8c-6d2d-4794-a1e7-5389a7c4c244","subtype":"Figure","type":"Plot"},"ticker":{"id":"27326341-052a-40ad-9311-267703222794","type":"BasicTicker"}},"id":"b80c6c3c-b94f-4a2c-8e12-a17466f0aca2","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1127dfe9-7e96-4a3b-81fc-442e9c854e11","type":"PanTool"},{"id":"e6b656c3-1a6b-4a26-a571-05cf5de3cba5","type":"WheelZoomTool"},{"id":"ceb4f82f-f246-44a1-8305-f08d61727534","type":"BoxZoomTool"},{"id":"6af68dd5-3efd-4706-bd4d-c819341b2f62","type":"SaveTool"},{"id":"1fa5e5b5-421e-4195-939b-39b59f474437","type":"ResetTool"},{"id":"aabf9cc3-b3f9-4fd8-9c8d-67b60ece705a","type":"HelpTool"}]},"id":"376eaa6c-4856-410e-bb5e-7389bb4e8265","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"058bcc06-3571-4eca-8b72-35dd97075895","type":"Patches"},{"attributes":{"data_source":{"id":"403578e9-0b85-4572-8294-291ba3e74fd0","type":"ColumnDataSource"},"glyph":{"id":"131b9c26-5981-4afa-b127-7e918d76992b","type":"Patches"},"hover_ ...

# %% [markdown]
# ### `strict_cut=True`
#
# Now for `strict_cut=True`. This mode allow you to find particles which have fewer than the specified number of particles. For this system, we'll search for 8 neighbors, so that we can display particles with both a deficit and a surplus of neighbors.

# %%
# create freud nearest neighbor object
# set number of neighbors
n_neigh = 8
# create freud nearest neighbors object
nn = locality.NearestNeighbors(rmax=1.23,n_neigh=n_neigh,strict_cut=True)
# grab data from last frame
l_box = box_data[-1]
l_pos = pos_data[-1]
l_quat = quat_data[-1]
l_ang = 2*np.arctan2(np.copy(l_quat[:,3]), np.copy(l_quat[:,0]))

# create box
fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)
side_length = max(fbox.Lx, fbox.Ly)
l_min = -side_length / 2.0
l_max = -l_min

# compute nearest neighbors for 6 nearest neighbors
start_time = time.time()
nn.compute(fbox, l_pos, l_pos)
stop_time = time.time()
print("time to calc 1 frame = {}".format(stop_time-start_time))
# get the neighborlist
n_list = nn.getNeighborList()
# get the number of particles
num_particles = nn.getNRef()
# now for array manipulation magic
# create an integer array of the same shape as the neighbor list array
int_arr = np.ones(shape=n_list.shape, dtype=np.int32)
# "search" for non-indexed particles (missing neighbors)
# while it would be most accurate to use the UINTMAX value
# provided by nn.getUINTMAX(), but this works just as well
int_arr[n_list > (num_particles-1)] = 0
# sum along particle index axis to determine the number of neighbors per particle
n_neighbors = np.sum(int_arr, axis=1)
# find the complement (if desired) to find number of missing neighbors per particle
n_deficits = n_neigh - n_neighbors
# only render particles with 5 neighbors
# find the proper shape for the array
# 5 neighbors + 1 central particle
c_idxs = np.where(n_neighbors==5)[0]
# this will be filled in first with the deficit particles, then the neighbors
draw_pos = np.zeros(shape=(6*len(c_idxs), 3),dtype=np.float32)
draw_ang = np.zeros(shape=(6*len(c_idxs)),dtype=np.float32)

draw_pos[:len(c_idxs)] = l_pos[c_idxs]
draw_ang[:len(c_idxs)] = l_ang[c_idxs]


for i, pidx in enumerate(c_idxs):
    # create a list of positions, angles to draw
    n_idxs = n_list[pidx,:5]
    for j, nidx in enumerate(n_idxs):
        draw_pos[len(c_idxs)+5*i+j] = l_pos[nidx]
        draw_ang[len(c_idxs)+5*i+j] = l_ang[nidx]

# render in bokeh
# vertex positions for hexagons
verts = [[0.537284965911771, 0.31020161970069976],
         [3.7988742065678664e-17, 0.6204032394013997],
         [-0.5372849659117709, 0.31020161970070004],
         [-0.5372849659117711, -0.31020161970069976],
         [-1.1396622619703597e-16, -0.6204032394013997],
         [0.5372849659117711, -0.3102016197006997]]
verts = np.array(verts)
# create array of transformed positions
patches = local_to_global(verts, draw_pos[:,0:2], draw_ang)
# turn into list of colors
c_list = ["#30A2DA", "#FC4F30", "#E5AE38", "#6D904F", "#9757DB",
    "#188487", "#FF7F00", "#9A2C66", "#626DDA", "#8B8B8B"]
# bokeh (as of this version) requires hex colors, so convert rgb to hex
hex_color = np.array([c_list[1] for _ in range(draw_pos.shape[0])])
hex_color[:len(c_idxs)] = c_list[0]
# for i in range(len(c_idxs)):
#     hex_color[6*i] = c_list[0]
# plot
p = figure(title="Nearest Neighbors visualization",x_range=(l_min, l_max), y_range=(l_min, l_max))
p.patches(xs=patches[:,:,0].tolist(), ys=patches[:,:,1].tolist(),
    fill_color=hex_color.tolist(), line_color="black")
# box display
p.patches(xs=[[-fbox.Lx/2, fbox.Lx/2, fbox.Lx/2, -fbox.Lx/2]],
          ys=[[-fbox.Ly/2, -fbox.Ly/2, fbox.Ly/2, fbox.Ly/2]],
          fill_color=(0,0,0,0), line_color="black", line_width=2)
default_bokeh(p)
show(p)

# black magic for quick position to rsq computation
# given an array Np x 3 (x,y,z), find the distance each particle is from the origin
# rsq = np.einsum("ij,ij->i", pos, pos)
# some kind of plotting thing here
# plt.plot(rsq, n_neighbors)
# Out:
# time to calc 1 frame = 0.011548042297363281
#     <div class="bk-root">
#         <div class="plotdiv" id="5faf3f93-9b17-4f4e-8de0-e3b67d203ff8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5faf3f93-9b17-4f4e-8de0-e3b67d203ff8").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5faf3f93-9b17-4f4e-8de0-e3b67d203ff8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5faf3f93-9b17-4f4e-8de0-e3b67d203ff8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1f1bf511-016b-48b7-abf7-5c653a54a089":{"roots":{"references":[{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"04234d3d-2858-4f9e-a519-29f6faf7c09a","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"},"ticker":{"id":"50ed11b1-b2c8-41b7-912c-09a5b66f0643","type":"BasicTicker"}},"id":"5491d9c1-9e2a-4fd4-8833-a111959fe754","type":"LinearAxis"},{"attributes":{"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"}},"id":"eb3407b9-0a36-4f26-be39-c2e2782e6528","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"},"ticker":{"id":"8c947821-f813-4fe5-99ce-3cadbddfd538","type":"BasicTicker"}},"id":"964d7470-efc9-40ab-a63c-6736b71bf0f6","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"eb3407b9-0a36-4f26-be39-c2e2782e6528","type":"PanTool"},{"id":"ddfd78d2-7bef-4dcb-941c-5c105e53ff2b","type":"WheelZoomTool"},{"id":"98aec37f-28d2-4840-9391-96c5a8c0e478","type":"BoxZoomTool"},{"id":"1cec64dc-9ba3-495c-9674-7204b7a4c222","type":"SaveTool"},{"id":"ef5a69e9-6834-40d8-b83d-ec58406e6c3d","type":"ResetTool"},{"id":"eea5062f-fb12-4864-8191-0ee958dc0005","type":"HelpTool"}]},"id":"644c6549-00be-47ea-a27f-1928486f213e","type":"Toolbar"},{"attributes":{"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"}},"id":"ef5a69e9-6834-40d8-b83d-ec58406e6c3d","type":"ResetTool"},{"attributes":{"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"}},"id":"eea5062f-fb12-4864-8191-0ee958dc0005","type":"HelpTool"},{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"bd0d4805-c7a1-4616-b492-b940ab5adb76","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"},"ticker":{"id":"8c947821-f813-4fe5-99ce-3cadbddfd538","type":"BasicTicker"}},"id":"2e35fe29-4ca4-4257-8af8-91f650cb7c7c","type":"LinearAxis"},{"attributes":{"overlay":{"id":"49f6cd64-67fc-4a0d-a940-d87acfc04733","type":"BoxAnnotation"},"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"}},"id":"98aec37f-28d2-4840-9391-96c5a8c0e478","type":"BoxZoomTool"},{"attributes":{},"id":"2217b610-9bf5-428b-9a55-7e1c7f28dc8c","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"49f6cd64-67fc-4a0d-a940-d87acfc04733","type":"BoxAnnotation"},{"attributes":{"fill_color":{"field":"fill_color"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"52db880d-903a-4ce6-9eb1-a4a67380012a","type":"Patches"},{"attributes":{"plot":{"id":"b40b0284-5856-4c38-8369-fc1b18181ab0","subtype":"Figure","type":"Plot"}},"id":"1cec64dc-9ba3-495c-9674-7204b7a4c222","type":"SaveTool"},{"attributes":{"fill_color":{"value":"rgba(0, 0, 0, 0)"},"line_width":{"value":2},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"371b3a9c-b56c-4bdd-b91b-b0a2ab066f62","type":"Patches"},{"attributes":{"callback":null,"column_names":["ys","xs","fill_color"],"data":{"fill_color":["#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A2DA","#30A ...

# %%
from freud import box, locality
# load the data
data_path = "ex_data/phi075"
box_data = np.load("{}/box_data.npy".format(data_path))
pos_data = np.load("{}/pos_data.npy".format(data_path))
quat_data = np.load("{}/quat_data.npy".format(data_path))
n_frames = pos_data.shape[0]

# create freud nearest neighbor object
# set number of neighbors
n_neigh = 6
# create freud nearest neighbors object
nn = locality.NearestNeighbors(rmax=1.5,n_neigh=n_neigh,strict_cut=True)
# grab data from last frame
l_box = box_data[-1]
l_pos = pos_data[-1]
l_quat = quat_data[-1]
l_ang = 2*np.arctan2(np.copy(l_quat[:,3]), np.copy(l_quat[:,0]))

# create box
fbox = box.Box(Lx=l_box["Lx"], Ly=l_box["Ly"], is2D=True)

# compute hexatic order for 6 nearest neighbors
start_time = time.time()
nn.compute(fbox, l_pos, l_pos)
stop_time = time.time()
print("time to calc 1 frame = {}".format(stop_time-start_time))
# get the neighborlist
n_list = nn.getNeighborList()
# get the number of particles
num_particles = nn.getNRef()
# now for array manipulation magic
# create an integer array of the same shape as the neighbor list array
int_arr = np.ones(shape=n_list.shape, dtype=np.int32)
# "search" for non-indexed particles (missing neighbors)
int_arr[n_list > (num_particles-1)] = 0
# sum along particle index axis to determine the number of neighbors per particle
n_neighbors = np.sum(int_arr, axis=1)
# find the complement (if desired) to find number of missing neighbors per particle
n_deficits = n_neigh - n_neighbors

# render in bokeh
# vertex positions for hexagons
verts = [[0.537284965911771, 0.31020161970069976],
         [3.7988742065678664e-17, 0.6204032394013997],
         [-0.5372849659117709, 0.31020161970070004],
         [-0.5372849659117711, -0.31020161970069976],
         [-1.1396622619703597e-16, -0.6204032394013997],
         [0.5372849659117711, -0.3102016197006997]]
verts = np.array(verts)
# create array of transformed positions
patches = local_to_global(verts, l_pos[:,0:2], l_ang)
# turn into list of colors
c_list = ["#30A2DA", "#FC4F30", "#E5AE38", "#6D904F", "#9757DB",
    "#188487", "#FF7F00", "#9A2C66", "#626DDA", "#8B8B8B"]
# bokeh (as of this version) requires hex colors, so convert rgb to hex
hex_color = [c_list[x] for x in n_neighbors]
# plot
p = figure(title="Nearest Neighbors visualization")
p.patches(xs=patches[:,:,0].tolist(), ys=patches[:,:,1].tolist(),
    fill_color=hex_color, line_color="black")
default_bokeh(p)
show(p)

# black magic for quick position to rsq computation
# given an array Np x 3 (x,y,z), find the distance each particle is from the origin
# rsq = np.einsum("ij,ij->i", pos, pos)
# some kind of plotting thing here
# plt.plot(rsq, n_neighbors)
# Out:
# time to calc 1 frame = 0.010183095932006836
#     <div class="bk-root">
#         <div class="plotdiv" id="3f8b9ab0-268c-43df-a5af-64679a608ffb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3f8b9ab0-268c-43df-a5af-64679a608ffb").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3f8b9ab0-268c-43df-a5af-64679a608ffb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3f8b9ab0-268c-43df-a5af-64679a608ffb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9eff4be6-8c49-4988-8319-7c62d1c4ae28":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b2881a88-188a-4e59-ae07-93d8ecbd8e77","type":"BoxAnnotation"},{"attributes":{},"id":"c7ea6260-6521-4df2-a2a2-ed869ee8ce6a","type":"BasicTicker"},{"attributes":{"data_source":{"id":"bd078405-a8d3-46a5-ad59-7e8c84573d03","type":"ColumnDataSource"},"glyph":{"id":"601d439d-3743-428e-a3af-179a28d705e1","type":"Patches"},"hover_glyph":null,"nonselection_glyph":{"id":"5132a652-973b-4c86-9162-8b93d880b8f8","type":"Patches"},"selection_glyph":null},"id":"0545da3f-c4ed-418f-9776-a3597b87c485","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"e5f0b366-ad18-4b70-88af-018c3be4b595","type":"DataRange1d"},{"attributes":{"plot":{"id":"f072e4f0-3ece-4c42-ac6f-a88542285907","subtype":"Figure","type":"Plot"}},"id":"429d2a6f-4895-4883-8235-413dca893523","type":"PanTool"},{"attributes":{},"id":"2bd010c1-cdea-4213-ada1-5af34375ab4a","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"429d2a6f-4895-4883-8235-413dca893523","type":"PanTool"},{"id":"8cf2a0b3-8684-4be9-9608-48b4bd7e12d3","type":"WheelZoomTool"},{"id":"078c628a-42ad-45fa-b6f7-c281250e6264","type":"BoxZoomTool"},{"id":"1ddbe698-10cf-4a48-a44b-f9755d4ca6b4","type":"SaveTool"},{"id":"a639dc44-d852-4cd9-add0-0d56993bef54","type":"ResetTool"},{"id":"a392c1b8-4169-4cba-a969-2b95c4ce2339","type":"HelpTool"}]},"id":"a4afb396-00ca-463d-a15a-ca97be8805aa","type":"Toolbar"},{"attributes":{"fill_color":{"field":"fill_color"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"601d439d-3743-428e-a3af-179a28d705e1","type":"Patches"},{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"e611a89c-79b8-4f5b-bdd6-271cadc5f246","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"f072e4f0-3ece-4c42-ac6f-a88542285907","subtype":"Figure","type":"Plot"},"ticker":{"id":"c7ea6260-6521-4df2-a2a2-ed869ee8ce6a","type":"BasicTicker"}},"id":"8d8ed712-6e59-42a8-b8d3-4b26bcd312ab","type":"LinearAxis"},{"attributes":{"plot":{"id":"f072e4f0-3ece-4c42-ac6f-a88542285907","subtype":"Figure","type":"Plot"}},"id":"1ddbe698-10cf-4a48-a44b-f9755d4ca6b4","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"5132a652-973b-4c86-9162-8b93d880b8f8","type":"Patches"},{"attributes":{"plot":{"id":"f072e4f0-3ece-4c42-ac6f-a88542285907","subtype":"Figure","type":"Plot"},"ticker":{"id":"2bd010c1-cdea-4213-ada1-5af34375ab4a","type":"BasicTicker"}},"id":"ad14a1be-a5d8-4dd5-ad90-ebaa27062e3d","type":"Grid"},{"attributes":{"axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"9d2b3eed-b3a5-4d05-8d3d-60f93a94e2a5","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"12pt"},"major_tick_in":10,"major_tick_out":0,"minor_tick_in":5,"minor_tick_out":0,"plot":{"id":"f072e4f0-3ece-4c42-ac6f-a88542285907","subtype":"Figure","type":"Plot"},"ticker":{"id":"2bd010c1-cdea-4213-ada1-5af34375ab4a","type":"BasicTicker"}},"id":"132b11af-4d11-4fcf-8410-798df1e27c41","type":"LinearAxis"},{"attributes":{},"id":"9d2b3eed-b3a5-4d05-8d3d-60f93a94e2a5","type":"BasicTickFormatter"},{"attributes":{"align":"center","plot":null,"text":"Nearest Neighbors visualization","text_font_size":{"value":"18pt"}},"id":"62d2ca5c-f22b-4d17-8122-ef931d4995be","type":"Title"},{"attributes":{},"id":"bb2785b8-09d8-4e83-99ef-45efed1159d1","type":"ToolEvents"},{"attributes":{"overlay":{"id":"b2881a88-188a- ...
